# %%
# conditional statements in python
1. python have 4 types of conditional statements
2. `if` statement 
3.`elif` statement
4.`else` statement
5. `nested` statements

```python
if(condition):
    statements
    statements..
```

```python if,else
if(condition):
    statements
    statements...
else:
    statements
    statements...
```
```python if,elif,else
if(condition):
    statement
elif(condition):
    statements
elif(condition):
    statement
else:
    statements..
```

# %%
#write a program to find the given number is even number 
num=int(input("please enter number here:"))
if(num%2 == 0):   
   print(num,"is even number")
# Out:
# please enter number here: 123

# %%
# write a program to find the given number is even number or odd number
number = int(input("please enter number here:"))
if(number%2 == 0):
            print(number,"is even number")
else:       
            print(number,"is odd number")
# Out:
# please enter number here: 4567
# 4567 is odd number

# %%
# Out:
# 1

# %%
#wite a program to find the given number is postive or negitive or zero
n = int(input("please enter number here:"))
if (n>0):
    print(n,"is positive")
elif(n<0):          
    print(n,"is negative")
else:
    print(n,"is zero")
# Out:
# please enter number here: 0
# 0 is zero

# %%
"""
wite a program to find the student grades based on marks
1. if student marks in between 100 to 80 then grade is A
2. if student marks in between 79 to 60 then grade is B
3. if student marks in between 59 to 40 then grade is c
4. if student marks in between 39 to 25 then grade is D
5. if student marks in between 24 to 0 then grade is fail
6. if other than above marks expected in output should be please enter correct marks!
"""
marks=int(input(Enter students markes here:))

# %%
##### 
marks = int(input("Enter student marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"is A grade")
elif (marks>=60 and marks<=90):
    print(marks, "is B grade")   
elif (marks>=40 and marks<=59):
    print(marks, "is C grade")
elif (marks>=25 and marks<=39):
    print(marks, "is D grade")
elif (marks>=0 and marks<=24):
    print(marks, "is fail")   
else:
    print(marks, "is not correct marks ,please enter correct marks")
# Out:
# Enter student marks here: 2345
# 2345 is not correct marks ,please enter correct marks

# %% [markdown]
# a=int(input("enter first number")
# b=int(input("enter second number")
# c=int(input("enter third number")
# if(a>=b and a>=c):
#       print(a,"is largest number")
# elif(b>=a and b>=c):
#        print(b,"is largest number")
# else:
#        princt(c,"is largest number")
